# %%
#importing pandas module
import pandas as pd

# %%
#To import the data using pandas
df = pd.read_csv('movie_metadata.csv')

# %%
# To print out the first five rows of data
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#print out hte first 10
df.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %%
#To check the last rows of data
df.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
df.describe(include= 'all')
# Out:
#         color     director_name  num_critic_for_reviews     duration  \
# count    5024              4939             4993.000000  5028.000000
# unique      2              2398                     NaN          NaN
# top     Color  Steven Spielberg                     NaN          NaN
# freq     4815                26                     NaN          NaN
# mean      NaN               NaN              140.194272   107.201074
# std       NaN               NaN              121.601675    25.197441
# min       NaN               NaN                1.000000     7.000000
# 25%       NaN               NaN               50.000000    93.000000
# 50%       NaN               NaN              110.000000   103.000000
# 75%       NaN               NaN              195.000000   118.000000
# max       NaN               NaN              813.000000   511.000000
#
#         director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
#To check for null values
df.isnull()
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     False          False                   False     False
# 1     False          False                   False     False
# 2     False          False                   False     False
# 3     False          False                   False     False
# 4      True          False                    True      True
# ...     ...            ...                     ...       ...
# 5038  False          False                   False     False
# 5039  False           True                   False     False
# 5040  False          False                   False     False
# 5041  False          False                   False     False
# 5042  False          False                   False     False
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                       False                   False         False
# 1                       False                   False         False
# ...

# %%
#to add up null values for each column
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
#To add up the total number of null values
df.isnull().sum().sum()
# Out:
# 2698

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.shape
# Out:
# (5043, 28)

# %%
#creating a capy
df1 = df.copy()

# %%
df1
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
#Dropping duplicate values
df3 = df.drop_duplicates()

# %%
df1.drop_duplicates(inplace= True)

# %%
df1.shape
# Out:
# (4998, 28)

# %%
df3.shape
# Out:
# (4998, 28)

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df['gross']
# Out:
# 0       760505847.0
# 1       309404152.0
# 2       200074175.0
# 3       448130642.0
# 4               NaN
#            ...
# 5038            NaN
# 5039            NaN
# 5040            NaN
# 5041        10443.0
# 5042        85222.0
# Name: gross, Length: 5043, dtype: float64

# %%
df.gross
# Out:
# 0       760505847.0
# 1       309404152.0
# 2       200074175.0
# 3       448130642.0
# 4               NaN
#            ...
# 5038            NaN
# 5039            NaN
# 5040            NaN
# 5041        10443.0
# 5042        85222.0
# Name: gross, Length: 5043, dtype: float64

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
df1.duration.mean()
# Out:
# 107.21332530604053

# %%
df1.duration.max()/ 60
# Out:
# 8.516666666666667

# %%
df1.loc[3]
# Out:
# color                                                                    Color
# director_name                                                Christopher Nolan
# num_critic_for_reviews                                                   813.0
# duration                                                                 164.0
# director_facebook_likes                                                22000.0
# actor_3_facebook_likes                                                 23000.0
# actor_2_name                                                    Christian Bale
# actor_1_facebook_likes                                                 27000.0
# gross                                                              448130642.0
# genres                                                         Action|Thriller
# actor_1_name                                                         Tom Hardy
# movie_title                                             The Dark Knight Rises
# ...

# %%
df1.duration.idxmax()
# Out:
# 1710

# %%
#Creating a new column
df1['movie_like'] = df1.cast_total_facebook_likes - df1.actor_2_facebook_likes
df1
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df1.shape
# Out:
# (4998, 29)

# %%
#to find the maximum  value of movie duration
df1.duration.max()
# Out:
# 511.0

# %%
#To find the location of the maximum value
df1.duration.idxmax()
# Out:
# 1710

# %%
#to print out thedetails of the movie with highest duration
df1.loc[df1.duration.idxmax()]
# Out:
# color                                                                    Color
# director_name                                                              NaN
# num_critic_for_reviews                                                    16.0
# duration                                                                 511.0
# director_facebook_likes                                                    NaN
# actor_3_facebook_likes                                                    51.0
# actor_2_name                                          Ingvar Eggert Sigurðsson
# actor_1_facebook_likes                                                   147.0
# gross                                                                      NaN
# genres                                                    Crime|Drama|Thriller
# actor_1_name                                             Ólafur Darri Ólafsson
# movie_title                                               Trapped
# ...

# %%
df1 = df1.rename(columns={
    'actor_1_name': 'Main_actor',
    'actor_2_name': 'Field_actor',
    'actor_3_name' : 'Sup_Actor',
    'actor_1_facebook_likes': 'MA_Likes',
    'actor_2_facebook_likes': 'FA_Likes',
    'actor_3_facebook_likes': 'SA_Likes'
})         
df1.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'SA_Likes', 'Field_actor', 'MA_Likes',
#        'gross', 'genres', 'Main_actor', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'Sup_Actor', 'facenumber_in_poster',
#        'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language',
#        'country', 'content_rating', 'budget', 'title_year', 'FA_Likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'movie_like'],
#       dtype='object')

# %%
df1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  SA_Likes       Field_actor  MA_Likes        gross  \
# 0                      0.0     855.0  Joel David Moore    1000.0  760505847.0
# 1                    563.0    1000.0     Orlando Bloom   40000.0  309404152.0
# 2                      0.0     161.0      Rory Kinnear   11000.0  200074175.0
# 3                  22000.0   23000.0    Christian Bale   27000.0  448130642.0
# 4                    131.0       NaN        Rob Walker     131.0          NaN
#
#                             genres  ... language country  content_rating  \
# ...

# %%
-*
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  SA_Likes       Field_actor  MA_Likes  \
# 0                         0.0     855.0  Joel David Moore    1000.0
# ...

# %% [markdown]
# Dealing with Missing Data

# %%
#to fill up missing data
df1.fillna(value = 12)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4        12        Doug Walker                    12.0      12.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                 12                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  SA_Likes       Field_actor  MA_Likes  \
# 0                         0.0     855.0  Joel David Moore    1000.0
# ...

# %%
values = {
    'color': 'color',
    'num_critic_for_reviews': 300
}
df5 = df1.fillna(value = values)
df5.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  color        Doug Walker                   300.0       NaN
#
#    director_facebook_likes  SA_Likes       Field_actor  MA_Likes        gross  \
# 0                      0.0     855.0  Joel David Moore    1000.0  760505847.0
# 1                    563.0    1000.0     Orlando Bloom   40000.0  309404152.0
# 2                      0.0     161.0      Rory Kinnear   11000.0  200074175.0
# 3                  22000.0   23000.0    Christian Bale   27000.0  448130642.0
# 4                    131.0       NaN        Rob Walker     131.0          NaN
#
#                             genres  ... language country  content_rating  \
# ...

# %%
df6 = df1.copy()
df6.color.fillna('color', inplace=True)
df6.num_critic_for_reviews.fillna(value = round(df1.num_critic_for_reviews.mean(),2),inplace = True)
df6
# df1.num_critic_for_reviews.mean()
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                  723.00     178.0
# 1     Color     Gore Verbinski                  302.00     169.0
# 2     Color         Sam Mendes                  602.00     148.0
# 3     Color  Christopher Nolan                  813.00     164.0
# 4     color        Doug Walker                  139.89       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                    1.00      87.0
# 5039  Color                NaN                   43.00      43.0
# 5040  Color   Benjamin Roberds                   13.00      76.0
# 5041  Color        Daniel Hsia                   14.00     100.0
# 5042  Color           Jon Gunn                   43.00      90.0
#
#       director_facebook_likes  SA_Likes       Field_actor  MA_Likes  \
# 0                         0.0     855.0  Joel David Moore    1000.0
# ...

# %%
df1
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  SA_Likes       Field_actor  MA_Likes  \
# 0                         0.0     855.0  Joel David Moore    1000.0
# ...

# %%
#Filling empty value with the previous row value
df7 = df1.fillna(method = 'ffill')
df7
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color        Doug Walker                   813.0     164.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color        Scott Smith                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  SA_Likes       Field_actor  MA_Likes  \
# 0                         0.0     855.0  Joel David Moore    1000.0
# ...

# %%
df8 = df1.fillna(method = 'bfill')
df8
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color        Doug Walker                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color   Benjamin Roberds                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  SA_Likes       Field_actor  MA_Likes  \
# 0                         0.0     855.0  Joel David Moore    1000.0
# ...

# %%
df9 = df1.fillna(method = 'ffill', axis = 1)
df9
# Out:
#       color      director_name num_critic_for_reviews     duration  \
# 0     Color      James Cameron                  723.0        178.0
# 1     Color     Gore Verbinski                  302.0        169.0
# 2     Color         Sam Mendes                  602.0        148.0
# 3     Color  Christopher Nolan                  813.0        164.0
# 4       NaN        Doug Walker            Doug Walker  Doug Walker
# ...     ...                ...                    ...          ...
# 5038  Color        Scott Smith                    1.0         87.0
# 5039  Color              Color                   43.0         43.0
# 5040  Color   Benjamin Roberds                   13.0         76.0
# 5041  Color        Daniel Hsia                   14.0        100.0
# 5042  Color           Jon Gunn                   43.0         90.0
#
#      director_facebook_likes SA_Likes       Field_actor MA_Likes        gross  \
# 0                        0.0    855.0  Joel David Moore   1000.0  760505847.0
# ...

# %%
df9.shape
# Out:
# (4998, 29)

# %%
#Dropping all missing values
df10 = df1.dropna()
df10.shape
# Out:
# (3723, 29)

# %%
df11 = df1.dropna(how = 'all')
df11.shape
# Out:
# (4998, 29)

# %%
df1.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'SA_Likes', 'Field_actor', 'MA_Likes',
#        'gross', 'genres', 'Main_actor', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'Sup_Actor', 'facenumber_in_poster',
#        'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language',
#        'country', 'content_rating', 'budget', 'title_year', 'FA_Likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'movie_like'],
#       dtype='object')

# %%
df1.drop(columns = ['num_critic_for_reviews', 'director_facebook_likes','SA_Likes','MA_Likes','FA_Likes','aspect_ratio'])
df1.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'SA_Likes', 'Field_actor', 'MA_Likes',
#        'gross', 'genres', 'Main_actor', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'Sup_Actor', 'facenumber_in_poster',
#        'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language',
#        'country', 'content_rating', 'budget', 'title_year', 'FA_Likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'movie_like'],
#       dtype='object')

# %%
df12 = df1.dropna()
df12.shape
# Out:
# (3723, 29)

# %%
884 +3723
# Out:
# 4607

# %%
mean = df1.groupby('genres')['gross'].mean()
# df1.gross.fillna(value = round(mean,2))
mean
# Out:
# genres
# Action                                                             5.952091e+07
# Action|Adventure                                                   1.307968e+08
# Action|Adventure|Animation|Comedy|Crime|Family|Fantasy             1.359691e+07
# Action|Adventure|Animation|Comedy|Drama|Family|Fantasy|Thriller             NaN
# Action|Adventure|Animation|Comedy|Drama|Family|Sci-Fi              1.228235e+08
#                                                                        ...
# Sci-Fi|Thriller                                                    2.979379e+07
# Thriller                                                           5.409697e+05
# Thriller|War                                                                NaN
# Thriller|Western                                                            NaN
# Western                                                            1.199322e+07
# Name: gross, Length: 914, dtype: float64

# %%
df1.isnull().sum()
# Out:
# color                         19
# director_name                103
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      103
# SA_Likes                      23
# Field_actor                   13
# MA_Likes                       7
# gross                        874
# genres                         0
# Main_actor                     7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# Sup_Actor                     23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               301
# budget                       487
# title_year                   107
# FA_Likes                      13
# imdb_score                     0
# aspect_ratio                 327
# movie_facebook_likes           0
# ...

# %%
df.genres
# Out:
# 0       Action|Adventure|Fantasy|Sci-Fi
# 1              Action|Adventure|Fantasy
# 2             Action|Adventure|Thriller
# 3                       Action|Thriller
# 4                           Documentary
#                      ...
# 5038                       Comedy|Drama
# 5039       Crime|Drama|Mystery|Thriller
# 5040              Drama|Horror|Thriller
# 5041               Comedy|Drama|Romance
# 5042                        Documentary
# Name: genres, Length: 5043, dtype: object

# %%
df1 = df1.sort_values(by='genres')

# %%
df1.head()
# Out:
#       color   director_name  num_critic_for_reviews  duration  \
# 4409    NaN  John Stockwell                     2.0      90.0
# 2697  Color             RZA                   208.0     107.0
# 4782  Color      Alec Asten                     1.0      82.0
# 2740  Color        Tony Jaa                   110.0     110.0
# 2814  Color     Chao-Bin Su                    50.0     117.0
#
#       director_facebook_likes  SA_Likes          Field_actor  MA_Likes  \
# 4409                    134.0     354.0           T.J. Storm  260000.0
# 2697                    561.0     353.0                  RZA     746.0
# 4782                      5.0     237.0    Dennis L.A. White     472.0
# 2740                      0.0       7.0  Petchtai Wongkamlao      64.0
# 2814                      2.0      21.0            Shawn Yue     149.0
#
#            gross  genres  ...  language   country  content_rating  \
# 4409         NaN  Action  ...       NaN       USA             NaN
# ...

# %%
df1.gross.fillna(method = 'ffill')
# Out:
# 4409           NaN
# 2697    15608545.0
# 4782    15608545.0
# 2740      102055.0
# 2814      102055.0
#            ...
# 4389    41400000.0
# 4369    41400000.0
# 4073      229094.0
# 4459      229094.0
# 3148      229094.0
# Name: gross, Length: 4998, dtype: float64

# %%
df1.isnull().sum()
# Out:
# color                         19
# director_name                103
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      103
# SA_Likes                      23
# Field_actor                   13
# MA_Likes                       7
# gross                        874
# genres                         0
# Main_actor                     7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# Sup_Actor                     23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               301
# budget                       487
# title_year                   107
# FA_Likes                      13
# imdb_score                     0
# aspect_ratio                 327
# movie_facebook_likes           0
# ...

# %%
df1.tail()
# Out:
#       color    director_name  num_critic_for_reviews  duration  \
# 4389  Color        John Ford                    55.0     103.0
# 4369  Color         Ted Post                    26.0     114.0
# 4073  Color     John Maclean                   246.0      84.0
# 4459  Color  Robert M. Young                     NaN     105.0
# 3148  Color      Walter Hill                    52.0     100.0
#
#       director_facebook_likes  SA_Likes       Field_actor  MA_Likes     gross  \
# 4389                    673.0      89.0       Ben Johnson     281.0       NaN
# 4369                     57.0     426.0        Bruce Dern   16000.0       NaN
# 4073                     85.0     748.0  Kodi Smit-McPhee   13000.0  229094.0
# 4459                      0.0     467.0      Bruce McGill     883.0       NaN
# 3148                    394.0     695.0   David Carradine    2000.0       NaN
#
#        genres  ... language country  content_rating      budget title_year  \
# ...

# %%
df1['gross']= df1['gross'].fillna(method = 'pad')

# %%
df1.tail()
# Out:
#       color    director_name  num_critic_for_reviews  duration  \
# 4389  Color        John Ford                    55.0     103.0
# 4369  Color         Ted Post                    26.0     114.0
# 4073  Color     John Maclean                   246.0      84.0
# 4459  Color  Robert M. Young                     NaN     105.0
# 3148  Color      Walter Hill                    52.0     100.0
#
#       director_facebook_likes  SA_Likes       Field_actor  MA_Likes  \
# 4389                    673.0      89.0       Ben Johnson     281.0
# 4369                     57.0     426.0        Bruce Dern   16000.0
# 4073                     85.0     748.0  Kodi Smit-McPhee   13000.0
# 4459                      0.0     467.0      Bruce McGill     883.0
# 3148                    394.0     695.0   David Carradine    2000.0
#
#            gross   genres  ... language country  content_rating      budget  \
# 4389  41400000.0  Western  ...  English     USA         Unrated   1600000.0
# ...

# %%
df1.isnull().sum()
# Out:
# color                         19
# director_name                103
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      103
# SA_Likes                      23
# Field_actor                   13
# MA_Likes                       7
# gross                          1
# genres                         0
# Main_actor                     7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# Sup_Actor                     23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               301
# budget                       487
# title_year                   107
# FA_Likes                      13
# imdb_score                     0
# aspect_ratio                 327
# movie_facebook_likes           0
# ...

# %%
df1['gross']= df1['gross'].fillna(method = 'bfill')

# %%
df1.head()
# Out:
#       color   director_name  num_critic_for_reviews  duration  \
# 4409    NaN  John Stockwell                     2.0      90.0
# 2697  Color             RZA                   208.0     107.0
# 4782  Color      Alec Asten                     1.0      82.0
# 2740  Color        Tony Jaa                   110.0     110.0
# 2814  Color     Chao-Bin Su                    50.0     117.0
#
#       director_facebook_likes  SA_Likes          Field_actor  MA_Likes  \
# 4409                    134.0     354.0           T.J. Storm  260000.0
# 2697                    561.0     353.0                  RZA     746.0
# 4782                      5.0     237.0    Dennis L.A. White     472.0
# 2740                      0.0       7.0  Petchtai Wongkamlao      64.0
# 2814                      2.0      21.0            Shawn Yue     149.0
#
#            gross  genres  ...  language   country  content_rating  \
# 4409  15608545.0  Action  ...       NaN       USA             NaN
# ...

# %%
df13 = df1.dropna()
df13.shape
# Out:
# (4101, 29)

# %% [markdown]
# Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'SA_Likes', 'Field_actor', 'MA_Likes',
#        'gross', 'genres', 'Main_actor', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'Sup_Actor', 'facenumber_in_poster',
#        'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language',
#        'country', 'content_rating', 'budget', 'title_year', 'FA_Likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'movie_like'],
#       dtype='object')

# %%
df1.plot.scatter(x = 'title_year', y = 'gross')
# Out:
# <Axes: xlabel='title_year', ylabel='gross'>

# %%
plt.figure( figsize=(12,5))
plt.scatter( df1['title_year'], df1['gross'])
plt.show()
# plt.xlabel('Movie_prod_year')

# %%
sns.scatterplot(data = df1, x = 'title_year', y = 'gross',  c = 'aquamarine', hue = 'duration')
# Out:
# <Axes: xlabel='title_year', ylabel='gross'>

# %%
df1.plot.bar(x= 'title_year',y = 'gross')
# Out:
# <Axes: xlabel='title_year'>
